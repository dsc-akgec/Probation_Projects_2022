# %% [markdown]
# ## Import all the modules

# %%
from fer import FER
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import matplotlib.pyplot as plt 
# %matplotlib inline
import cv2

# %% [markdown]
# ## Open chrome for opening the playlist

# %%
driver = webdriver.Chrome('./sources/chromedriver.exe')
# Out:
# C:\Users\Dark\AppData\Local\Temp\ipykernel_4132\480797217.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./sources/chromedriver.exe')

# %% [markdown]
# ## Reading a pre-saved image

# %%
emo_detector = FER(mtcnn=True)

# %% [markdown]
# ## Reading all the emotions using FER module

# %%
captured_emotions = emo_detector.detect_emotions(test_image_one)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 166/166 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 19ms/step

# %% [markdown]
# ## Print all the emotions from the image

# %%
print(captured_emotions)
plt.imshow(test_image_one)
# Out:
# [{'box': [2360, 711, 1617, 2396], 'emotions': {'angry': 0.99, 'disgust': 0.0, 'fear': 0.01, 'happy': 0.0, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.0}}]

# %% [markdown]
# ## Accessing the dominant emotion by it's score

# %%
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)
print(dominant_emotion, emotion_score)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 166/166 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 24ms/step
# angry 0.99

# %% [markdown]
# ## By dominant emotion we are directing to a playlist

# %%
if dominant_emotion == "happy":
    driver.get("https://open.spotify.com/playlist/4nd7oGDNgfM0rv28CQw9WQ")

elif dominant_emotion == "sad":
    driver.get("https://open.spotify.com/playlist/1jJoJu3y2v0pl2fQb4FpcR")
    
elif dominant_emotion == "angry":
    driver.get("https://open.spotify.com/playlist/2SAlj6IpdtsyI7qqU0ZKb2")
    
elif dominant_emotion == "fear":
    driver.get("https://open.spotify.com/album/1KwWAVnZPhsc9QlQGrM702")
    
elif dominant_emotion == "disgust":
    driver.get("https://open.spotify.com/playlist/7diEjS9gADBgVpDww9J1r3")
    
elif dominant_emotion == "neutral":
    driver.get("https://open.spotify.com/playlist/0ffnLxCftwLzmXDO7DJEXc")
    
elif dominant_emotion == "surprise":
    driver.get("https://open.spotify.com/playlist/2dBjcjjYckHQlrn8iHm7c1")

else:
    print("no face detected")
